# %% [markdown]
# # **SpaceX  Falcon 9 First Stage Landing Prediction**
# ## Data Web Dashboard

# %%
# !pip install dash
# Out:
# Requirement already satisfied: dash in c:\users\xigen\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\xigen\anaconda3\lib\site-packages (from dash) (1.10.1)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\xigen\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\xigen\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\xigen\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\xigen\anaconda3\lib\site-packages (from dash) (2.0.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\xigen\anaconda3\lib\site-packages (from dash) (5.4.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\xigen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\xigen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.0.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\xigen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: click>=7.1.2 in c:\users\xigen\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (8.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\xigen\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: six in c:\users\xigen\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (1.12.0)
# Requirement already satisfied: brotli in c:\users\xigen\anaconda3\lib\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: importlib-metadata in c:\users\xigen\anaconda3\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash) (4.8.2)
# Requirement already satisfied: colorama in c:\users\xigen\anaconda3\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\xigen\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: dataclasses in c:\users\xigen\anaconda3\lib\site-packages (from Werkzeug>=2.0->Flask>=1.0.4->dash) (0.8)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\xigen\anaconda3\lib\site-packages (from importlib-metadata->click>=7.1.2->Flask>=1.0.4->dash) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\xigen\anaconda3\lib\site-packages (from importlib-metadata->click>=7.1.2->Flask>=1.0.4->dash) (3.6.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\xigen\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\xigen\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
import plotly.express as px
# Out:
# C:\Users\xigen\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\xigen\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   after removing the cwd from sys.path.

# %%
spacex_df = pd.read_csv("C:/Users/xigen/Desktop/Cousera-IBM Data Science, Analyst, Engineer, etc/10.Applied Data Science Capstone/Week2-Exploratory Analysis EDA with SQL, PD, PLT, SNN/spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
print(max_payload, min_payload)
# Out:
# 9600.0 0.0

# %%
app = dash.Dash(__name__)

uniquelaunchsites = spacex_df['Launch Site'].unique().tolist()
lsites = []
lsites.append({'label': 'All Sites', 'value': 'All Sites'})
for site in uniquelaunchsites:
 lsites.append({'label': site, 'value': site})                                 
                           


app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                
                                dcc.Dropdown(id='site_dropdown',options=lsites,placeholder='Select a Launch Site here', searchable = True , value = 'All Sites'),
                                html.Br(),

                       
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                             
                                dcc.RangeSlider(
                                    id='payload_slider',
                                    min=0,
                                    max=10000,
                                    step=1000,  
                                    marks = {
                                            0: '0 kg',
                                            1000: '1000 kg',
                                            2000: '2000 kg',
                                            3000: '3000 kg',
                                            4000: '4000 kg',
                                            5000: '5000 kg',
                                            6000: '6000 kg',  
                                            7000: '7000 kg',
                                            8000: '8000 kg',
                                            9000: '9000 kg',
                                            10000: '10000 kg'                                         
                                    },

                                    value=[min_payload,max_payload]
                                ),
                            
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                              
                                ])

@app.callback(
     Output(component_id='success-pie-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value')]               
)
def update_graph(site_dropdown):
    if (site_dropdown == 'All Sites'):
        df  = spacex_df[spacex_df['class'] == 1]
        fig = px.pie(df, names = 'Launch Site',hole=.3,title = 'Total Success Launches By all sites')
    else:
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        fig = px.pie(df, names = 'class',hole=.3,title = 'Total Success Launches for site '+site_dropdown)
    return fig

@app.callback(
     Output(component_id='success-payload-scatter-chart',component_property='figure'),
     [Input(component_id='site_dropdown',component_property='value'),Input(component_id="payload_slider", component_property="value")]               
)
def update_scattergraph(site_dropdown,payload_slider):
    if site_dropdown == 'All Sites':
        low, high = payload_slider
        df  = spacex_df
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class", 
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    else:
        low, high = payload_slider
        df  = spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        mask = (df['Payload Mass (kg)'] > low) & (df['Payload Mass (kg)'] < high)
        fig = px.scatter(
            df[mask], x="Payload Mass (kg)", y="class", 
            color="Booster Version",
            size='Payload Mass (kg)',
            hover_data=['Payload Mass (kg)'])
    return fig


if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_0_0m1637912076.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/deps/react@16.v2_0_0m1637912076.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_0_0m1637912076.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_0_0m1637912076.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_0_0m1637912076.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_0_0m1637912076.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_0_0m1637912076.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_0m1637912076.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dash_table/bundle.v5_0_0m1637912076.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:06] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:20:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:26:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:26:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:26:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:26:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:27:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:27:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:27:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:27:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:27:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:27:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:33:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:33:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:33:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:34:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:35:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:35:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:36:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:38:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:38:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:38:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:39:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:39:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:40:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:41:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:41:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:41:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:41:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:41:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:41:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:42:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:43:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:44:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:44:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:46:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:46:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:47:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 11:47:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_0_0m1637912076.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/deps/react@16.v2_0_0m1637912076.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_0_0m1637912076.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_0_0m1637912076.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_0_0m1637912076.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_0_0m1637912076.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_0_0m1637912076.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_0m1637912076.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dash_table/bundle.v5_0_0m1637912076.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:54] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [27/Nov/2021 20:39:55] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### Author : Ashlin Darius Govindasamy
# #### ADGSTUDIOS
